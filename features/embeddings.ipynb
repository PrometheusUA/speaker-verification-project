# %% [markdown]
# # Spectrogram embeddings

# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Obtaining dependency information for librosa from https://files.pythonhosted.org/packages/e2/a2/4f639c1168d7aada749a896afb4892a831e2041bebdcf636aebfe9e86556/librosa-0.10.1-py3-none-any.whl.metadata
#   Downloading librosa-0.10.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Obtaining dependency information for audioread>=2.1.9 from https://files.pythonhosted.org/packages/57/8d/30aa32745af16af0a9a650115fbe81bde7c610ed5c21b381fca0196f3a7f/audioread-3.0.1-py3-none-any.whl.metadata
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from librosa) (1.24.3)
# Requirement already satisfied: scipy>=1.2.0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from librosa) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from librosa) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from librosa) (0.57.0)
# Collecting soundfile>=0.12.1 (from librosa)
#   Obtaining dependency information for soundfile>=0.12.1 from https://files.pythonhosted.org/packages/c8/73/059c84343be6509b480013bf1eeb11b96c5f9eb48deff8f83638011f6b2c/soundfile-0.12.1-py2.py3-none-macosx_10_9_x86_64.whl.metadata
#   Downloading soundfile-0.12.1-py2.py3-none-macosx_10_9_x86_64.whl.metadata (14 kB)
# Collecting pooch>=1.0 (from librosa)
#   Obtaining dependency information for pooch>=1.0 from https://files.pythonhosted.org/packages/f4/72/8ae0f1ba4ce6a4f6d4d01a60a9fdf690fde188c45c1872b0b4ddb0607ace/pooch-1.8.1-py3-none-any.whl.metadata
#   Downloading pooch-1.8.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Obtaining dependency information for soxr>=0.3.2 from https://files.pythonhosted.org/packages/1c/5a/61572e3d1f5dd4c9c0a32d9f7f57b7b6089222227c881fe0945cf955261f/soxr-0.3.7-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading soxr-0.3.7-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from librosa) (4.10.0)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from numba>=0.51.0->librosa) (0.40.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2024.2.2)
# Downloading librosa-0.10.1-py3-none-any.whl (253 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.7/253.7 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading pooch-1.8.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 2.4 MB/s eta 0:00:00
# Downloading soundfile-0.12.1-py2.py3-none-macosx_10_9_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 8.7 MB/s eta 0:00:00ta 0:00:01
# Downloading soxr-0.3.7-cp311-cp311-macosx_10_9_x86_64.whl (414 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 414.4/414.4 kB 6.1 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: soxr, audioread, soundfile, pooch, librosa
# Successfully installed audioread-3.0.1 librosa-0.10.1 pooch-1.8.1 soundfile-0.12.1 soxr-0.3.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.lib import stride_tricks
import scipy.io.wavfile as wav
from scipy.fftpack import fft
from scipy.signal import get_window
import librosa
import librosa.display
import os
import glob
from tqdm import tqdm
import pandas as pd

# %%
def spectrogram_embedding(y, sr, n_mels=256):
    mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels)
    embedding = np.mean(mel, axis=1)
    return embedding

# %%
WAV_DIRECTORY = '../data/wav/'

embedding_map = {}

wav_files = glob.glob(os.path.join(WAV_DIRECTORY, '**', '*.wav'), recursive=True)

for wav_path in tqdm(wav_files):
    y, sr = librosa.load(wav_path)
    
    embedding = spectrogram_embedding(y=y, sr=sr)
    
    file_id = wav_path.replace(WAV_DIRECTORY, '')
    embedding_map[file_id] = embedding
# Out:
# 100%|███████████████████████████████████| 153516/153516 [46:15<00:00, 55.31it/s]

# %%
embedding_df = pd.DataFrame.from_dict(embedding_map, orient="index")

embedding_df.index.name = 'file_id'
embedding_df = embedding_df.add_prefix('x_')

embedding_df.to_csv('spectrogram_embeddings.csv')
# Out:
#                                     x_0       x_1       x_2       x_3  \
# file_id
# id10384/vxBFGKGXSFA/00006.wav  0.051118  0.075810  0.077973  0.875630
# id10384/vxBFGKGXSFA/00007.wav  0.042835  0.062862  0.066601  0.406492
# id10384/vxBFGKGXSFA/00005.wav  0.039275  0.060451  0.069024  0.217769
# id10384/vxBFGKGXSFA/00004.wav  0.057395  0.079640  0.080750  0.435038
# id10384/vxBFGKGXSFA/00001.wav  0.046767  0.063620  0.062323  0.608490
#
#                                     x_4       x_5       x_6       x_7  \
# file_id
# id10384/vxBFGKGXSFA/00006.wav  4.209989  1.813636  0.334108  0.165719
# id10384/vxBFGKGXSFA/00007.wav  1.580761  0.658935  0.189841  0.172900
# id10384/vxBFGKGXSFA/00005.wav  1.003179  1.240808  0.538822  0.145850
# id10384/vxBFGKGXSFA/00004.wav  1.668968  0.724695  0.213150  0.172010
# id10384/vxBFGKGXSFA/00001.wav  2.282021  0.864586  0.282813  0.196223
#
#                                     x_8       x_9  ...         x_246  \
# file_id                                            ...
# id10384/vxBFGKGXSFA/00006.wav  0.421833  0.602115  ...  5.824187e-06
# id10384/vxBFGKGXSFA/00007.wav  0.371853  0.575293  ...  3.605826e-07
# id10384/vxBFGKGXSFA/00005.wav  0.230882  0.424917  ...  3.075610e-09
# id10384/vxBFGKGXSFA/00004.wav  0.334640  0.582857  ...  1.256977e-07
# id10384/vxBFGKGXSFA/00001.wav  0.390590  0.653713  ...  1.233509e-07
#
#                                       x_247         x_248         x_249  \
# file_id
# id10384/vxBFGKGXSFA/00006.wav  5.744669e-06  5.673987e-06  5.617007e-06
# id10384/vxBFGKGXSFA/00007.wav  3.555249e-07  3.510333e-07  3.474087e-07
# id10384/vxBFGKGXSFA/00005.wav  2.816975e-09  2.597574e-09  2.414698e-09
# id10384/vxBFGKGXSFA/00004.wav  1.234602e-07  1.214354e-07  1.197388e-07
# id10384/vxBFGKGXSFA/00001.wav  1.210096e-07  1.189437e-07  1.172473e-07
#
#                                       x_250         x_251         x_252  \
# file_id
# id10384/vxBFGKGXSFA/00006.wav  5.573508e-06  5.535287e-06  5.500909e-06
# id10384/vxBFGKGXSFA/00007.wav  3.446305e-07  3.421867e-07  3.400112e-07
# id10384/vxBFGKGXSFA/00005.wav  2.264260e-09  2.139767e-09  2.038914e-09
# id10384/vxBFGKGXSFA/00004.wav  1.183725e-07  1.171670e-07  1.161054e-07
# id10384/vxBFGKGXSFA/00001.wav  1.159059e-07  1.147468e-07  1.137367e-07
#
#                                       x_253         x_254         x_255
# file_id
# id10384/vxBFGKGXSFA/00006.wav  5.477081e-06  5.467958e-06  5.445129e-06
# id10384/vxBFGKGXSFA/00007.wav  3.384883e-07  3.378854e-07  3.364562e-07
# id10384/vxBFGKGXSFA/00005.wav  1.962609e-09  1.911178e-09  1.874295e-09
# id10384/vxBFGKGXSFA/00004.wav  1.153295e-07  1.149353e-07  1.143309e-07
# id10384/vxBFGKGXSFA/00001.wav  1.130110e-07  1.126547e-07  1.120826e-07
#
# [5 rows x 256 columns]

# %% [markdown]
# # X-vector embeddings

# %%
# !pip install speechbrain
# Out:
# Collecting speechbrain
#   Obtaining dependency information for speechbrain from https://files.pythonhosted.org/packages/90/ee/c8669b57ebdbeac0530538725caa02cd226e2623b725f1e216ae59b54a1f/speechbrain-1.0.0-py3-none-any.whl.metadata
#   Downloading speechbrain-1.0.0-py3-none-any.whl.metadata (23 kB)
# Collecting hyperpyyaml (from speechbrain)
#   Obtaining dependency information for hyperpyyaml from https://files.pythonhosted.org/packages/33/c9/751b6401887f4b50f9307cc1e53d287b3dc77c375c126aeb6335aff73ccb/HyperPyYAML-1.2.2-py3-none-any.whl.metadata
#   Downloading HyperPyYAML-1.2.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from speechbrain) (1.2.0)
# Requirement already satisfied: numpy in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from speechbrain) (1.24.3)
# Requirement already satisfied: packaging in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from speechbrain) (23.1)
# Requirement already satisfied: scipy in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from speechbrain) (1.11.1)
# Requirement already satisfied: sentencepiece in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from speechbrain) (0.1.99)
# Requirement already satisfied: torch>=1.9 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from speechbrain) (2.2.1)
# Requirement already satisfied: torchaudio in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from speechbrain) (2.2.1)
# Requirement already satisfied: tqdm in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from speechbrain) (4.65.0)
# Requirement already satisfied: huggingface-hub in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from speechbrain) (0.15.1)
# Requirement already satisfied: filelock in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (4.10.0)
# Requirement already satisfied: sympy in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (1.11.1)
# Requirement already satisfied: networkx in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (3.1)
# Requirement already satisfied: jinja2 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (3.1.2)
# Requirement already satisfied: fsspec in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from torch>=1.9->speechbrain) (2023.4.0)
# Requirement already satisfied: requests in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from huggingface-hub->speechbrain) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from huggingface-hub->speechbrain) (6.0)
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain)
#   Obtaining dependency information for ruamel.yaml>=0.17.28 from https://files.pythonhosted.org/packages/73/67/8ece580cc363331d9a53055130f86b096bf16e38156e33b1d3014fffda6b/ruamel.yaml-0.18.6-py3-none-any.whl.metadata
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain)
#   Obtaining dependency information for ruamel.yaml.clib>=0.2.7 from https://files.pythonhosted.org/packages/b1/15/971b385c098e8d0d170893f5ba558452bb7b776a0c90658b8f4dd0e3382b/ruamel.yaml.clib-0.2.8-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading ruamel.yaml.clib-0.2.8-cp311-cp311-macosx_10_9_universal2.whl.metadata (2.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.9->speechbrain) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->speechbrain) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/mpalamariuk/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.9->speechbrain) (1.3.0)
# Downloading speechbrain-1.0.0-py3-none-any.whl (760 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.1/760.1 kB 7.3 MB/s eta 0:00:00a 0:00:01
# Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 4.9 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.8-cp311-cp311-macosx_10_9_universal2.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.9/148.9 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, ruamel.yaml, hyperpyyaml, speechbrain
#   Attempting uninstall: ruamel.yaml
#     Found existing installation: ruamel.yaml 0.17.21
#     Uninstalling ruamel.yaml-0.17.21:
#       Successfully uninstalled ruamel.yaml-0.17.21
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda 23.7.4 requires ruamel-yaml<0.18,>=0.11.14, but you have ruamel-yaml 0.18.6 which is incompatible.
# Successfully installed hyperpyyaml-1.2.2 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 speechbrain-1.0.0

# %%
from speechbrain.inference.speaker import EncoderClassifier
from tqdm import tqdm
import numpy as np
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from numpy.lib import stride_tricks
import scipy.io.wavfile as wav
from scipy.fftpack import fft
from scipy.signal import get_window
import librosa
import librosa.display
import os
import glob
from tqdm import tqdm
import pandas as pd

# %%
classifier = EncoderClassifier.from_hparams(source="speechbrain/spkrec-xvect-voxceleb", savedir="pretrained_models/spkrec-xvect-voxceleb")
# Out:
# Downloading hyperparams.yaml:   0%|          | 0.00/2.04k [00:00<?, ?B/s]
# Downloading embedding_model.ckpt:   0%|          | 0.00/16.9M [00:00<?, ?B/s]
# Downloading mean_var_norm_emb.ckpt:   0%|          | 0.00/3.20k [00:00<?, ?B/s]
# Downloading classifier.ckpt:   0%|          | 0.00/15.9M [00:00<?, ?B/s]
# Downloading label_encoder.txt:   0%|          | 0.00/129k [00:00<?, ?B/s]

# %%
WAV_DIRECTORY = '../data/wav/'

embedding_map = {}

wav_files = glob.glob(os.path.join(WAV_DIRECTORY, '**', '*.wav'), recursive=True)

for wav_path in tqdm(wav_files):
    signal, fs = torchaudio.load(wav_path)
    embedding = classifier.encode_batch(signal)
    
    file_id = wav_path.replace(WAV_DIRECTORY, '')
    embedding_map[file_id] = embedding[0, 0].numpy()
# Out:
# 100%|█████████████████████████████████| 153516/153516 [1:27:38<00:00, 29.20it/s]

# %%
embedding_df = pd.DataFrame.from_dict(embedding_map, orient="index")

embedding_df.index.name = 'file_id'
embedding_df = embedding_df.add_prefix('x_')

embedding_df.to_csv('x_vector_embeddings.csv')
# Out:
#                                      x_0       x_1        x_2        x_3  \
# file_id
# id10384/vxBFGKGXSFA/00006.wav -23.354128 -5.221647  12.240580  15.430451
# id10384/vxBFGKGXSFA/00007.wav -24.505468 -8.043333   8.051411  11.658402
# id10384/vxBFGKGXSFA/00005.wav -25.886944 -6.220237  12.843323  12.866706
# id10384/vxBFGKGXSFA/00004.wav -26.685034 -7.005956  10.387636  13.525033
# id10384/vxBFGKGXSFA/00001.wav -28.967779 -8.300890  12.400032  11.168025
#
#                                     x_4       x_5        x_6        x_7  \
# file_id
# id10384/vxBFGKGXSFA/00006.wav  1.791511 -0.519118 -20.509670 -12.181440
# id10384/vxBFGKGXSFA/00007.wav -0.395556 -8.682104 -19.021248 -10.961925
# id10384/vxBFGKGXSFA/00005.wav  5.178396 -1.025675 -19.521687  -9.459463
# id10384/vxBFGKGXSFA/00004.wav  0.917440 -6.970324 -21.471519 -10.747233
# id10384/vxBFGKGXSFA/00001.wav  1.290220 -7.722721 -17.906452  -8.237776
#
#                                      x_8       x_9  ...      x_502     x_503  \
# file_id                                             ...
# id10384/vxBFGKGXSFA/00006.wav  11.994558  5.631124  ... -26.862387  6.170730
# id10384/vxBFGKGXSFA/00007.wav  12.948086  5.389829  ... -26.868261  6.515625
# id10384/vxBFGKGXSFA/00005.wav  12.362989  5.665018  ... -24.904192  3.411289
# id10384/vxBFGKGXSFA/00004.wav   9.679843  6.068498  ... -24.744322  8.596687
# id10384/vxBFGKGXSFA/00001.wav  11.434650  5.865917  ... -22.426640  3.674269
#
#                                    x_504     x_505      x_506      x_507  \
# file_id
# id10384/vxBFGKGXSFA/00006.wav  -5.671959 -3.804694 -16.238195  11.366379
# id10384/vxBFGKGXSFA/00007.wav  -3.996622 -4.034167 -16.338655   8.985258
# id10384/vxBFGKGXSFA/00005.wav  -3.564738 -3.262426 -13.783454   6.580886
# id10384/vxBFGKGXSFA/00004.wav -11.971527 -4.305787 -19.009026  11.050454
# id10384/vxBFGKGXSFA/00001.wav  -6.918116 -3.619047 -10.661541   9.406233
#
#                                    x_508      x_509      x_510      x_511
# file_id
# id10384/vxBFGKGXSFA/00006.wav  17.722548   7.378318  11.428824 -19.350277
# id10384/vxBFGKGXSFA/00007.wav  14.625571  11.528162   8.261323 -19.290039
# id10384/vxBFGKGXSFA/00005.wav  14.320321   9.416150  11.227883 -17.160492
# id10384/vxBFGKGXSFA/00004.wav  15.358821   6.720806   9.944366 -21.631676
# id10384/vxBFGKGXSFA/00001.wav  12.912198  11.073880   9.938466 -20.352184
#
# [5 rows x 512 columns]
